# %%
import pandas as pd

url = "https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/diabetes.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
translation = {
    'Pregnancies': 'Homiladorlik',
    'Glucose': 'glyukoza',
    'BloodPressure': 'qon bosimi',
    'SkinThickness': 'teri qalinligi',
    'Insulin': 'insulin',
    'BMI': 'tana massasi indeksi',
    'DiabetesPedigreeFunction': 'qandli diabet irsiy omili'
}
df.rename(columns=translation,inplace=True)

df.head()
# Out:
#    Homiladorlik  glyukoza  qon bosimi  teri qalinligi  insulin  \
# 0             6       148          72              35        0
# 1             1        85          66              29        0
# 2             8       183          64               0        0
# 3             1        89          66              23       94
# 4             0       137          40              35      168
#
#    tana massasi indeksi  qandli diabet irsiy omili  Age  Outcome
# 0                  33.6                      0.627   50        1
# 1                  26.6                      0.351   31        0
# 2                  23.3                      0.672   32        1
# 3                  28.1                      0.167   21        0
# 4                  43.1                      2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Homiladorlik               768 non-null    int64
#  1   glyukoza                   768 non-null    int64
#  2   qon bosimi                 768 non-null    int64
#  3   teri qalinligi             768 non-null    int64
#  4   insulin                    768 non-null    int64
#  5   tana massasi indeksi       768 non-null    float64
#  6   qandli diabet irsiy omili  768 non-null    float64
#  7   Age                        768 non-null    int64
#  8   Outcome                    768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Homiladorlik    glyukoza  qon bosimi  teri qalinligi     insulin  \
# count    768.000000  768.000000  768.000000      768.000000  768.000000
# mean       3.845052  120.894531   69.105469       20.536458   79.799479
# std        3.369578   31.972618   19.355807       15.952218  115.244002
# min        0.000000    0.000000    0.000000        0.000000    0.000000
# 25%        1.000000   99.000000   62.000000        0.000000    0.000000
# 50%        3.000000  117.000000   72.000000       23.000000   30.500000
# 75%        6.000000  140.250000   80.000000       32.000000  127.250000
# max       17.000000  199.000000  122.000000       99.000000  846.000000
#
#        tana massasi indeksi  qandli diabet irsiy omili         Age     Outcome
# count            768.000000                 768.000000  768.000000  768.000000
# mean              31.992578                   0.471876   33.240885    0.348958
# std                7.884160                   0.331329   11.760232    0.476951
# ...

# %%
df.value_counts()
# Out:
# Homiladorlik  glyukoza  qon bosimi  teri qalinligi  insulin  tana massasi indeksi  qandli diabet irsiy omili  Age  Outcome
# 12            140       82          43              325      39.2                  0.528                      58   1          1
#               121       78          17              0        26.5                  0.259                      62   0          1
#               106       80          0               0        23.6                  0.137                      44   0          1
#               100       84          33              105      30.0                  0.488                      46   0          1
#               92        62          7               258      27.6                  0.926                      44   1          1
#                                                                                                                              ..
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.shape
# Out:
# (768, 9)

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.corrwith(df['Outcome']).abs().sort_values(ascending=False)
# Out:
# Outcome                      1.000000
# glyukoza                     0.466581
# tana massasi indeksi         0.292695
# Age                          0.238356
# Homiladorlik                 0.221898
# qandli diabet irsiy omili    0.173844
# insulin                      0.130548
# teri qalinligi               0.074752
# qon bosimi                   0.065068
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Homiladorlik                 0
# glyukoza                     0
# qon bosimi                   0
# teri qalinligi               0
# insulin                      0
# tana massasi indeksi         0
# qandli diabet irsiy omili    0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
x= df.drop('Outcome', axis=1).values
y= df['Outcome']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
TR= scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(TR,y, test_size=0.2, random_state=12)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=15)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
y_predict = knn.predict(X_test)

# %%
from sklearn.metrics import jaccard_score

jaccard_score(y_test, y_predict)
# Out:
# np.float64(0.5454545454545454)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(confusion_matrix(y_test, y_predict), annot=True)
plt.show()

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[88, 11],
#        [19, 36]])

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
precision = precision_score(y_test, y_predict)
recall = recall_score(y_test, y_predict)
f1 = f1_score(y_test, y_predict)
accuracy = accuracy_score(y_test, y_predict)
print(f"{precision=}\n{recall=}\n{f1=}\n{accuracy=}")
# Out:
# precision=0.7659574468085106
# recall=0.6545454545454545
# f1=0.7058823529411765
# accuracy=0.8051948051948052

# %%
from sklearn.model_selection import cross_val_predict
predict = cross_val_predict(estimator = knn, X =TR, y = y, cv = 5)
from sklearn.metrics import classification_report
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83       500
#            1       0.71      0.54      0.61       268
#
#     accuracy                           0.76       768
#    macro avg       0.74      0.71      0.72       768
# weighted avg       0.76      0.76      0.75       768

# %%
f1 = []
for k in range(1,25):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_predict = knn.predict(X_test)
    f1.append(f1_score(y_test, y_predict))

plt.figure(figsize=(10,6))
plt.plot(range(1,25),f1)
plt.xticks(range(1,25))
plt.grid()
plt.show()

# %%
import pickle
filename = 'knn_model.pkl'
with open(filename, 'wb') as f:
    pickle.dump(knn, f)
print(f"Trained KNN model saved to {filename}")
# Out:
# Trained KNN model saved to knn_model.pkl
